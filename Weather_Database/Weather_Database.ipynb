# %%
# Importing Dependencies

import pandas as pd

import matplotlib.pyplot as plt

import numpy as np

import requests

import time

from citipy import citipy

from config import weather_api_key

# %%
# Creating a random set of 2000 latitudes and longitudes
# storing them in variables
# packing the latitude and longitude values as pairs using the zip function

lats = np.random.uniform(-90.000, 90.000, size=2000)

lngs = np.random.uniform(-180.000, 180.000, size=2000)

lats_lngs = zip(lats, lngs)

lats_lngs

# %%
# Using citipy to assign cities to those coordinates

# converting zip to a list

coordinates = list(lats_lngs)

# creating an empty list to hold the cities
cities = []

# identifying nearest city for each lat lng pair

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # if the city name is unique, add to cities[]
    
    if city not in cities:
        cities.append(city)

print(len(cities))
# Out:
# 771

# %%
# Performing API call with OpenWeatherMap
# Retrieving Lat, Lng, Max temp, % Humidity, % Cloudiness, Wind Speed, Weather desc.

url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + weather_api_key

# creating empty list to hold the data

city_data = []

# print to note beginning of the log

print("Beginning Data Retrieval        ")
print("--------------------------------")

# creating the counters

record_count = 1

set_count = 1

# for loop with enumerate method

for i, city in enumerate(cities):
    if (i % 50 ==0 and i> 50):
        set_count += 1
        
        record_count = 1
        
        time.sleep(60)

    # Creating endpoint URL with each city
    
    city_url = url + "&q=" + city.replace(" ", "+")
    
    print(f"Processing Record {record_count} of set {set_count} | {city}")
    
    # Adding 1 to record_count
    
    record_count += 1
    
    # Using try-except to run the API
    
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        
        # Parse the needed data
        
        city_lat = city_weather['coord']['lat']
        
        city_lng = city_weather['coord']['lon']
        
        city_max_temp = city_weather["main"]["temp_max"]
        
        city_humidity = city_weather["main"]["humidity"]
        
        city_clouds = city_weather["clouds"]["all"]
        
        city_wind = city_weather["wind"]["speed"]
        
        city_country = city_weather["sys"]["country"]
        
        city_description = city_weather["weather"][0]["description"] 
        
        # Append city information to the city_data list
        
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})
    
    # if error, skip the city:
    
    except:
        
        print("City not found. Skipping...")
        
        pass
    
print("-------------------------------")

print("Data Retrieval Complete")

print("-------------------------------")
# Out:
# Beginning Data Retrieval
# --------------------------------
# Processing Record 1 of set 1 | pisco
# Processing Record 2 of set 1 | xuddur
# Processing Record 3 of set 1 | saleaula
# City not found. Skipping...
# Processing Record 4 of set 1 | avera
# Processing Record 5 of set 1 | yellowknife
# Processing Record 6 of set 1 | ushuaia
# Processing Record 7 of set 1 | jamestown
# Processing Record 8 of set 1 | castro
# Processing Record 9 of set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of set 1 | ritchie
# Processing Record 11 of set 1 | petatlan
# Processing Record 12 of set 1 | tuatapere
# Processing Record 13 of set 1 | hobart
# Processing Record 14 of set 1 | carlisle
# Processing Record 15 of set 1 | qui nhon
# Processing Record 16 of set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 17 of set 1 | busselton
# Processing Record 18 of set 1 | dicabisagan
# Processing Record 19 of set 1 | moussoro
# Processing Record 20 of set 1 | erzurum
# Processing Record 21 of set 1 | thompson
# Processing Record 22 of set 1 | half moon bay
# Processing Record 23 of set 1 | bredasdorp
# Processing Record 24 of set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of set 1 | bluff
# Processing Record 26 of set 1 | rikitea
# Processing Record 27 of set 1 | tuktoyaktuk
# Processing Record 28 of set 1 | arraial do cabo
# Processing Record 29 of set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 30 of set 1 | kokopo
# Processing Record 31 of set 1 | qaanaaq
# Processing Record 32 of set 1 | lubao
# Processing Record 33 of set 1 | shalya
# Processing Record 34 of set 1 | allapalli
# Processing Record 35 of set 1 | albany
# Processing Record 36 of set 1 | labytnangi
# Processing Record 37 of set 1 | carnarvon
# Processing Record 38 of set 1 | provideniya
# Processing Record 39 of set 1 | dingle
# Processing Record 40 of set 1 | banda aceh
# Processing Record 41 of set 1 | esperance
# Processing Record 42 of set 1 | narsaq
# Processing Record 43 of set 1 | catamarca
# Processing Record 44 of set 1 | koroni
# Processing Record 45 of set 1 | taksimo
# Processing Record 46 of set 1 | rawson
# Processing Record 47 of set 1 | coquimbo
# Processing Record 48 of set 1 | havoysund
# Processing Record 49 of set 1 | khatanga
# Processing Record 50 of set 1 | tubruq
# City not found. Skipping...
# Processing Record 51 of set 1 | cape town
# Processing Record 52 of set 1 | atuona
# Processing Record 53 of set 1 | lebu
# Processing Record 54 of set 1 | hermanus
# Processing Record 55 of set 1 | abu zabad
# Processing Record 56 of set 1 | hithadhoo
# Processing Record 57 of set 1 | martin
# Processing Record 58 of set 1 | nikolskoye
# Processing Record 59 of set 1 | dauriya
# Processing Record 60 of set 1 | tulagi
# Processing Record 61 of set 1 | katakwi
# Processing Record 62 of set 1 | plettenberg bay
# Processing Record 63 of set 1 | balezino
# Processing Record 64 of set 1 | antofagasta
# Processing Record 65 of set 1 | qaqortoq
# Processing Record 66 of set 1 | tasiilaq
# Processing Record 67 of set 1 | sao joao da barra
# Processing Record 68 of set 1 | quatre cocos
# Processing Record 69 of set 1 | ancud
# Processing Record 70 of set 1 | severo-kurilsk
# Processing Record 71 of set 1 | dubti
# Processing Record 72 of set 1 | barranca
# Processing Record 73 of set 1 | lompoc
# Processing Record 74 of set 1 | lapua
# Processing Record 75 of set 1 | saskylakh
# Processing Record 76 of set 1 | safford
# Processing Record 77 of set 1 | aksu
# Processing Record 78 of set 1 | georgetown
# Processing Record 79 of set 1 | vaini
# Processing Record 80 of set 1 | meyungs
# City not found. Skipping...
# Processing Record 81 of set 1 | nampula
# Processing Record 82 of set 1 | barrow
# Processing Record 83 of set 1 | avarua
# Processing Record 84 of set 1 | zhigansk
# Processing Record 85 of set 1 | zhangye
# Processing Record 86 of set 1 | punta arenas
# Processing Record 87 of set 1 | fortuna
# Processing Record 88 of set 1 | rapid valley
# Processing Record 89 of set 1 | butaritari
# Processing Record 90 of set 1 | wilmington
# Processing Record 91 of set 1 | puerto ayora
# Processing Record 92 of set 1 | port lincoln
# Processing Record 93 of set 1 | candiis
# Processing Record 94 of set 1 | east london
# Processing Record 95 of set 1 | loreto
# Processing Record 96 of set 1 | hasaki
# Processing Record 97 of set 1 | ponta do sol
# Processing Record 98 of set 1 | iqaluit
# Processing Record 99 of set 1 | kapaa
# Processing Record 100 of set 1 | nsoko
# Processing Record 1 of set 2 | caravelas
# Processing Record 2 of set 2 | bethel
# Processing Record 3 of set 2 | mataura
# Processing Record 4 of set 2 | cabo san lucas
# Processing Record 5 of set 2 | mpraeso
# Processing Record 6 of set 2 | melfort
# Processing Record 7 of set 2 | tangua
# Processing Record 8 of set 2 | airai
# Processing Record 9 of set 2 | clyde river
# Processing Record 10 of set 2 | anyama
# Processing Record 11 of set 2 | ilulissat
# Processing Record 12 of set 2 | geraldton
# Processing Record 13 of set 2 | cabedelo
# Processing Record 14 of set 2 | portland
# Processing Record 15 of set 2 | yulara
# Processing Record 16 of set 2 | new norfolk
# Processing Record 17 of set 2 | saint-philippe
# Processing Record 18 of set 2 | luganville
# Processing Record 19 of set 2 | santiago de cao
# Processing Record 20 of set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 21 of set 2 | hilo
# Processing Record 22 of set 2 | tevaitoa
# Processing Record 23 of set 2 | bolobo
# Processing Record 24 of set 2 | yekaterinovka
# Processing Record 25 of set 2 | vestmannaeyjar
# Processing Record 26 of set 2 | hofn
# Processing Record 27 of set 2 | mar del plata
# Processing Record 28 of set 2 | saint george
# Processing Record 29 of set 2 | chulman
# Processing Record 30 of set 2 | vajszlo
# Processing Record 31 of set 2 | haines junction
# Processing Record 32 of set 2 | upernavik
# Processing Record 33 of set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 34 of set 2 | hargeysa
# Processing Record 35 of set 2 | sola
# Processing Record 36 of set 2 | berlevag
# Processing Record 37 of set 2 | chuy
# Processing Record 38 of set 2 | arlit
# Processing Record 39 of set 2 | pevek
# Processing Record 40 of set 2 | marienburg
# Processing Record 41 of set 2 | victoria
# Processing Record 42 of set 2 | manono
# Processing Record 43 of set 2 | nome
# Processing Record 44 of set 2 | santa lucia
# Processing Record 45 of set 2 | reriutaba
# Processing Record 46 of set 2 | wyndham
# Processing Record 47 of set 2 | khorixas
# Processing Record 48 of set 2 | wanning
# Processing Record 49 of set 2 | salsomaggiore terme
# Processing Record 50 of set 2 | wajir
# Processing Record 1 of set 3 | barentsburg
# City not found. Skipping...
# Processing Record 2 of set 3 | kuusankoski
# Processing Record 3 of set 3 | durg
# Processing Record 4 of set 3 | nishihara
# Processing Record 5 of set 3 | verkhnyaya inta
# Processing Record 6 of set 3 | halalo
# City not found. Skipping...
# Processing Record 7 of set 3 | dikson
# Processing Record 8 of set 3 | port keats
# Processing Record 9 of set 3 | tabat
# Processing Record 10 of set 3 | san patricio
# Processing Record 11 of set 3 | talnakh
# Processing Record 12 of set 3 | bolshoye soldatskoye
# City not found. Skipping...
# Processing Record 13 of set 3 | turukhansk
# Processing Record 14 of set 3 | lima
# Processing Record 15 of set 3 | tiksi
# Processing Record 16 of set 3 | semirom
# Processing Record 17 of set 3 | along
# Processing Record 18 of set 3 | port alfred
# Processing Record 19 of set 3 | encrucijada
# Processing Record 20 of set 3 | pecos
# Processing Record 21 of set 3 | singapore
# Processing Record 22 of set 3 | alofi
# Processing Record 23 of set 3 | longyearbyen
# Processing Record 24 of set 3 | songea
# Processing Record 25 of set 3 | wewak
# Processing Record 26 of set 3 | henties bay
# Processing Record 27 of set 3 | ati
# Processing Record 28 of set 3 | rognan
# Processing Record 29 of set 3 | sim
# Processing Record 30 of set 3 | bonoua
# Processing Record 31 of set 3 | poronaysk
# Processing Record 32 of set 3 | khorramabad
# Processing Record 33 of set 3 | jabinyanah
# Processing Record 34 of set 3 | christchurch
# Processing Record 35 of set 3 | constitucion
# Processing Record 36 of set 3 | daryapur
# Processing Record 37 of set 3 | teknaf
# Processing Record 38 of set 3 | fort nelson
# Processing Record 39 of set 3 | bowen
# Processing Record 40 of set 3 | diamantino
# Processing Record 41 of set 3 | sao gabriel da cachoeira
# Processing Record 42 of set 3 | kodiak
# Processing Record 43 of set 3 | ngunguru
# Processing Record 44 of set 3 | chokurdakh
# Processing Record 45 of set 3 | taolanaro
# City not found. Skipping...
# Processing Record 46 of set 3 | kungurtug
# Processing Record 47 of set 3 | sungaipenuh
# Processing Record 48 of set 3 | bosaso
# Processing Record 49 of set 3 | poum
# Processing Record 50 of set 3 | sakakah
# Processing Record 1 of set 4 | alice springs
# Processing Record 2 of set 4 | port hedland
# Processing Record 3 of set 4 | twin falls
# Processing Record 4 of set 4 | lagoa
# Processing Record 5 of set 4 | ha giang
# Processing Record 6 of set 4 | vila velha
# Processing Record 7 of set 4 | ketrzyn
# Processing Record 8 of set 4 | faanui
# Processing Record 9 of set 4 | oriximina
# Processing Record 10 of set 4 | karup
# Processing Record 11 of set 4 | bardiyah
# Processing Record 12 of set 4 | manerbio
# Processing Record 13 of set 4 | arrifes
# Processing Record 14 of set 4 | hauknes
# Processing Record 15 of set 4 | tera
# Processing Record 16 of set 4 | rungata
# City not found. Skipping...
# Processing Record 17 of set 4 | kahului
# Processing Record 18 of set 4 | torbay
# Processing Record 19 of set 4 | bambous virieux
# Processing Record 20 of set 4 | utiroa
# City not found. Skipping...
# Processing Record 21 of set 4 | itacoatiara
# Processing Record 22 of set 4 | augustow
# Processing Record 23 of set 4 | husavik
# Processing Record 24 of set 4 | morondava
# Processing Record 25 of set 4 | egvekinot
# Processing Record 26 of set 4 | pietarsaari
# Processing Record 27 of set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 28 of set 4 | broken hill
# Processing Record 29 of set 4 | ambulu
# Processing Record 30 of set 4 | nazas
# Processing Record 31 of set 4 | port blair
# Processing Record 32 of set 4 | meadow lake
# Processing Record 33 of set 4 | verkhnyaya sinyachikha
# Processing Record 34 of set 4 | port-gentil
# Processing Record 35 of set 4 | rushden
# Processing Record 36 of set 4 | ornskoldsvik
# Processing Record 37 of set 4 | santa marta
# Processing Record 38 of set 4 | riyadh
# Processing Record 39 of set 4 | tsihombe
# City not found. Skipping...
# Processing Record 40 of set 4 | mubi
# Processing Record 41 of set 4 | bahia honda
# Processing Record 42 of set 4 | west bay
# Processing Record 43 of set 4 | khasan
# Processing Record 44 of set 4 | kavieng
# Processing Record 45 of set 4 | hays
# Processing Record 46 of set 4 | vaitupu
# City not found. Skipping...
# Processing Record 47 of set 4 | san cristobal
# Processing Record 48 of set 4 | hutang
# Processing Record 49 of set 4 | victor harbor
# Processing Record 50 of set 4 | terney
# Processing Record 1 of set 5 | santa
# Processing Record 2 of set 5 | charters towers
# Processing Record 3 of set 5 | san jose de guanipa
# Processing Record 4 of set 5 | basco
# Processing Record 5 of set 5 | vanavara
# Processing Record 6 of set 5 | khandyga
# Processing Record 7 of set 5 | asyut
# Processing Record 8 of set 5 | jiexiu
# Processing Record 9 of set 5 | formosa
# Processing Record 10 of set 5 | amderma
# City not found. Skipping...
# Processing Record 11 of set 5 | tres arroyos
# Processing Record 12 of set 5 | soe
# Processing Record 13 of set 5 | bur gabo
# City not found. Skipping...
# Processing Record 14 of set 5 | sao filipe
# Processing Record 15 of set 5 | warqla
# City not found. Skipping...
# Processing Record 16 of set 5 | ormara
# Processing Record 17 of set 5 | yerofey pavlovich
# Processing Record 18 of set 5 | arman
# Processing Record 19 of set 5 | nerchinskiy zavod
# Processing Record 20 of set 5 | rocha
# Processing Record 21 of set 5 | tessalit
# Processing Record 22 of set 5 | peshkopi
# Processing Record 23 of set 5 | kadykchan
# City not found. Skipping...
# Processing Record 24 of set 5 | atasu
# Processing Record 25 of set 5 | slave lake
# Processing Record 26 of set 5 | helmsdale
# Processing Record 27 of set 5 | bekhtery
# Processing Record 28 of set 5 | sur
# Processing Record 29 of set 5 | cabildo
# Processing Record 30 of set 5 | belyy yar
# Processing Record 31 of set 5 | kushima
# Processing Record 32 of set 5 | tabuk
# Processing Record 33 of set 5 | liniere
# City not found. Skipping...
# Processing Record 34 of set 5 | yibin
# Processing Record 35 of set 5 | laguna
# Processing Record 36 of set 5 | ketchikan
# Processing Record 37 of set 5 | lasa
# Processing Record 38 of set 5 | baie-comeau
# Processing Record 39 of set 5 | kizukuri
# Processing Record 40 of set 5 | bintulu
# Processing Record 41 of set 5 | nago
# Processing Record 42 of set 5 | alta floresta
# Processing Record 43 of set 5 | vangaindrano
# Processing Record 44 of set 5 | hami
# Processing Record 45 of set 5 | carutapera
# Processing Record 46 of set 5 | sitka
# Processing Record 47 of set 5 | los llanos de aridane
# Processing Record 48 of set 5 | mareeba
# Processing Record 49 of set 5 | nyurba
# Processing Record 50 of set 5 | jumla
# Processing Record 1 of set 6 | toamasina
# Processing Record 2 of set 6 | davila
# Processing Record 3 of set 6 | camacha
# Processing Record 4 of set 6 | port hardy
# Processing Record 5 of set 6 | gorzow wielkopolski
# Processing Record 6 of set 6 | menongue
# Processing Record 7 of set 6 | codrington
# Processing Record 8 of set 6 | fuerte olimpo
# Processing Record 9 of set 6 | namibe
# Processing Record 10 of set 6 | cachoeira do sul
# Processing Record 11 of set 6 | hualmay
# Processing Record 12 of set 6 | port elizabeth
# Processing Record 13 of set 6 | flinders
# Processing Record 14 of set 6 | asadabad
# Processing Record 15 of set 6 | natal
# Processing Record 16 of set 6 | lahaina
# Processing Record 17 of set 6 | gat
# Processing Record 18 of set 6 | ribeira brava
# Processing Record 19 of set 6 | kanor
# Processing Record 20 of set 6 | salaga
# Processing Record 21 of set 6 | pyapon
# Processing Record 22 of set 6 | vao
# Processing Record 23 of set 6 | saldanha
# Processing Record 24 of set 6 | belushya guba
# City not found. Skipping...
# Processing Record 25 of set 6 | bulungu
# Processing Record 26 of set 6 | beloha
# Processing Record 27 of set 6 | sibiti
# Processing Record 28 of set 6 | gallipoli
# Processing Record 29 of set 6 | yar-sale
# Processing Record 30 of set 6 | norman wells
# Processing Record 31 of set 6 | guadalupe y calvo
# Processing Record 32 of set 6 | san giovanni in fiore
# Processing Record 33 of set 6 | bubaque
# Processing Record 34 of set 6 | faya
# Processing Record 35 of set 6 | aswan
# Processing Record 36 of set 6 | batagay-alyta
# Processing Record 37 of set 6 | padang
# Processing Record 38 of set 6 | urdzhar
# City not found. Skipping...
# Processing Record 39 of set 6 | santa cruz de la palma
# Processing Record 40 of set 6 | andenes
# Processing Record 41 of set 6 | nanortalik
# Processing Record 42 of set 6 | taitung
# Processing Record 43 of set 6 | thinadhoo
# Processing Record 44 of set 6 | wahran
# City not found. Skipping...
# Processing Record 45 of set 6 | tena
# Processing Record 46 of set 6 | shakhtinsk
# Processing Record 47 of set 6 | marcona
# City not found. Skipping...
# Processing Record 48 of set 6 | beinasco
# Processing Record 49 of set 6 | gamba
# Processing Record 50 of set 6 | belokurikha
# Processing Record 1 of set 7 | sahrak
# City not found. Skipping...
# Processing Record 2 of set 7 | simpang
# Processing Record 3 of set 7 | belaya gora
# Processing Record 4 of set 7 | bardsir
# Processing Record 5 of set 7 | srednekolymsk
# Processing Record 6 of set 7 | gayny
# Processing Record 7 of set 7 | hammerfest
# Processing Record 8 of set 7 | cooma
# Processing Record 9 of set 7 | maniitsoq
# Processing Record 10 of set 7 | guerrero negro
# Processing Record 11 of set 7 | altay
# Processing Record 12 of set 7 | adrar
# Processing Record 13 of set 7 | grand gaube
# Processing Record 14 of set 7 | powell river
# Processing Record 15 of set 7 | cascavel
# Processing Record 16 of set 7 | gravdal
# Processing Record 17 of set 7 | agua branca
# Processing Record 18 of set 7 | ahipara
# Processing Record 19 of set 7 | katsuura
# Processing Record 20 of set 7 | alihe
# Processing Record 21 of set 7 | dembi dolo
# Processing Record 22 of set 7 | anadyr
# Processing Record 23 of set 7 | hirara
# Processing Record 24 of set 7 | pandan
# Processing Record 25 of set 7 | vaitape
# Processing Record 26 of set 7 | lorengau
# Processing Record 27 of set 7 | lukiv
# Processing Record 28 of set 7 | willowmore
# Processing Record 29 of set 7 | luderitz
# Processing Record 30 of set 7 | carauari
# Processing Record 31 of set 7 | waingapu
# Processing Record 32 of set 7 | wulanhaote
# City not found. Skipping...
# Processing Record 33 of set 7 | garanhuns
# Processing Record 34 of set 7 | areosa
# Processing Record 35 of set 7 | cherskiy
# Processing Record 36 of set 7 | bud
# Processing Record 37 of set 7 | sambava
# Processing Record 38 of set 7 | tual
# Processing Record 39 of set 7 | baykit
# Processing Record 40 of set 7 | vestmanna
# Processing Record 41 of set 7 | nemuro
# Processing Record 42 of set 7 | mwinilunga
# Processing Record 43 of set 7 | medicine hat
# Processing Record 44 of set 7 | dujuma
# City not found. Skipping...
# Processing Record 45 of set 7 | vernon
# Processing Record 46 of set 7 | hambantota
# Processing Record 47 of set 7 | brownsville
# Processing Record 48 of set 7 | kudahuvadhoo
# Processing Record 49 of set 7 | xining
# Processing Record 50 of set 7 | hervey bay
# Processing Record 1 of set 8 | brigantine
# Processing Record 2 of set 8 | peterhead
# Processing Record 3 of set 8 | orcotuna
# Processing Record 4 of set 8 | mahebourg
# Processing Record 5 of set 8 | barinas
# Processing Record 6 of set 8 | emba
# Processing Record 7 of set 8 | isiro
# Processing Record 8 of set 8 | sarangani
# Processing Record 9 of set 8 | abbeville
# Processing Record 10 of set 8 | devils lake
# Processing Record 11 of set 8 | walvis bay
# Processing Record 12 of set 8 | kurchum
# Processing Record 13 of set 8 | port macquarie
# Processing Record 14 of set 8 | zeya
# Processing Record 15 of set 8 | okhotsk
# Processing Record 16 of set 8 | roma
# Processing Record 17 of set 8 | tabou
# Processing Record 18 of set 8 | ribeira grande
# Processing Record 19 of set 8 | kramat
# Processing Record 20 of set 8 | iquique
# Processing Record 21 of set 8 | lensk
# Processing Record 22 of set 8 | tazovskiy
# Processing Record 23 of set 8 | zverinogolovskoye
# Processing Record 24 of set 8 | tabas
# Processing Record 25 of set 8 | ucluelet
# Processing Record 26 of set 8 | orzhytsya
# Processing Record 27 of set 8 | rastolita
# Processing Record 28 of set 8 | dunedin
# Processing Record 29 of set 8 | sorvag
# City not found. Skipping...
# Processing Record 30 of set 8 | nalut
# Processing Record 31 of set 8 | cidreira
# Processing Record 32 of set 8 | tongliao
# Processing Record 33 of set 8 | naro moru
# Processing Record 34 of set 8 | san luis
# Processing Record 35 of set 8 | ullapool
# Processing Record 36 of set 8 | college
# Processing Record 37 of set 8 | collie
# Processing Record 38 of set 8 | mitchell
# Processing Record 39 of set 8 | xinmin
# Processing Record 40 of set 8 | korla
# Processing Record 41 of set 8 | asilah
# Processing Record 42 of set 8 | shieli
# Processing Record 43 of set 8 | alice
# Processing Record 44 of set 8 | sturgis
# Processing Record 45 of set 8 | mabaruma
# Processing Record 46 of set 8 | grand river south east
# City not found. Skipping...
# Processing Record 47 of set 8 | vila franca do campo
# Processing Record 48 of set 8 | the valley
# Processing Record 49 of set 8 | kourou
# Processing Record 50 of set 8 | mahon
# Processing Record 1 of set 9 | dibaya
# City not found. Skipping...
# Processing Record 2 of set 9 | lavrentiya
# Processing Record 3 of set 9 | livingston
# Processing Record 4 of set 9 | tulnici
# Processing Record 5 of set 9 | ende
# Processing Record 6 of set 9 | umm kaddadah
# Processing Record 7 of set 9 | yumen
# Processing Record 8 of set 9 | rudnyy
# Processing Record 9 of set 9 | hamilton
# Processing Record 10 of set 9 | karkaralinsk
# City not found. Skipping...
# Processing Record 11 of set 9 | mandali
# Processing Record 12 of set 9 | naze
# Processing Record 13 of set 9 | esmeraldas
# Processing Record 14 of set 9 | tezu
# Processing Record 15 of set 9 | otane
# Processing Record 16 of set 9 | beira
# Processing Record 17 of set 9 | souillac
# Processing Record 18 of set 9 | grand centre
# City not found. Skipping...
# Processing Record 19 of set 9 | mandan
# Processing Record 20 of set 9 | ouadda
# Processing Record 21 of set 9 | fairbanks
# Processing Record 22 of set 9 | launceston
# Processing Record 23 of set 9 | guiratinga
# Processing Record 24 of set 9 | pimentel
# Processing Record 25 of set 9 | bucerias
# Processing Record 26 of set 9 | chiredzi
# Processing Record 27 of set 9 | samarai
# Processing Record 28 of set 9 | mount gambier
# Processing Record 29 of set 9 | russell
# Processing Record 30 of set 9 | mahadday weyne
# City not found. Skipping...
# Processing Record 31 of set 9 | bima
# Processing Record 32 of set 9 | nantucket
# Processing Record 33 of set 9 | grao mogol
# Processing Record 34 of set 9 | presidencia roque saenz pena
# Processing Record 35 of set 9 | kirksville
# Processing Record 36 of set 9 | klaksvik
# Processing Record 37 of set 9 | bouna
# Processing Record 38 of set 9 | bengkulu
# Processing Record 39 of set 9 | phan thiet
# Processing Record 40 of set 9 | east wenatchee bench
# Processing Record 41 of set 9 | sept-iles
# Processing Record 42 of set 9 | algarrobo
# Processing Record 43 of set 9 | ligayan
# Processing Record 44 of set 9 | belmonte
# Processing Record 45 of set 9 | dhidhdhoo
# Processing Record 46 of set 9 | carballo
# Processing Record 47 of set 9 | ellisras
# Processing Record 48 of set 9 | makakilo city
# Processing Record 49 of set 9 | richards bay
# Processing Record 50 of set 9 | honiara
# Processing Record 1 of set 10 | adre
# Processing Record 2 of set 10 | dudinka
# Processing Record 3 of set 10 | trussville
# Processing Record 4 of set 10 | oulu
# Processing Record 5 of set 10 | praia
# Processing Record 6 of set 10 | mount isa
# Processing Record 7 of set 10 | dalian
# Processing Record 8 of set 10 | ostrovnoy
# Processing Record 9 of set 10 | kununurra
# Processing Record 10 of set 10 | chapais
# Processing Record 11 of set 10 | lamu
# Processing Record 12 of set 10 | fukue
# Processing Record 13 of set 10 | ambilobe
# Processing Record 14 of set 10 | mawlaik
# Processing Record 15 of set 10 | olga
# Processing Record 16 of set 10 | male
# Processing Record 17 of set 10 | yurimaguas
# Processing Record 18 of set 10 | carbondale
# Processing Record 19 of set 10 | el alto
# Processing Record 20 of set 10 | bentiu
# Processing Record 21 of set 10 | lata
# Processing Record 22 of set 10 | saint-joseph
# Processing Record 23 of set 10 | birobidzhan
# Processing Record 24 of set 10 | llangefni
# Processing Record 25 of set 10 | saint-augustin
# Processing Record 26 of set 10 | la rochelle
# Processing Record 27 of set 10 | dunmore town
# Processing Record 28 of set 10 | aykhal
# Processing Record 29 of set 10 | evensk
# Processing Record 30 of set 10 | cayenne
# Processing Record 31 of set 10 | lixourion
# Processing Record 32 of set 10 | hamina
# Processing Record 33 of set 10 | tura
# Processing Record 34 of set 10 | roald
# Processing Record 35 of set 10 | anori
# Processing Record 36 of set 10 | biak
# Processing Record 37 of set 10 | wagar
# Processing Record 38 of set 10 | maningrida
# Processing Record 39 of set 10 | ovsyanka
# Processing Record 40 of set 10 | rurrenabaque
# Processing Record 41 of set 10 | sabang
# Processing Record 42 of set 10 | jacareacanga
# Processing Record 43 of set 10 | la ronge
# Processing Record 44 of set 10 | mehamn
# Processing Record 45 of set 10 | sorland
# Processing Record 46 of set 10 | almaznyy
# Processing Record 47 of set 10 | querecotillo
# Processing Record 48 of set 10 | muros
# Processing Record 49 of set 10 | kieta
# Processing Record 50 of set 10 | soyo
# Processing Record 1 of set 11 | cartagena
# Processing Record 2 of set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 3 of set 11 | shinpokh
# Processing Record 4 of set 11 | alakurtti
# Processing Record 5 of set 11 | isangel
# Processing Record 6 of set 11 | alotau
# City not found. Skipping...
# Processing Record 7 of set 11 | durban
# Processing Record 8 of set 11 | bulawayo
# Processing Record 9 of set 11 | sayyan
# Processing Record 10 of set 11 | krasnoselkup
# Processing Record 11 of set 11 | karakendzha
# City not found. Skipping...
# Processing Record 12 of set 11 | forestville
# Processing Record 13 of set 11 | zhuhai
# Processing Record 14 of set 11 | punta alta
# Processing Record 15 of set 11 | vardo
# Processing Record 16 of set 11 | ambodifototra
# City not found. Skipping...
# Processing Record 17 of set 11 | bathsheba
# Processing Record 18 of set 11 | zhoucheng
# Processing Record 19 of set 11 | coahuayana
# Processing Record 20 of set 11 | srednebelaya
# Processing Record 21 of set 11 | vagur
# Processing Record 22 of set 11 | kirillov
# Processing Record 23 of set 11 | tamsalu
# Processing Record 24 of set 11 | cam pha
# City not found. Skipping...
# Processing Record 25 of set 11 | mirnyy
# Processing Record 26 of set 11 | nanzhang
# Processing Record 27 of set 11 | balikpapan
# Processing Record 28 of set 11 | krasnoarmeysk
# Processing Record 29 of set 11 | venustiano carranza
# Processing Record 30 of set 11 | inuvik
# Processing Record 31 of set 11 | suez
# Processing Record 32 of set 11 | tuy hoa
# Processing Record 33 of set 11 | bandarbeyla
# Processing Record 34 of set 11 | praya
# Processing Record 35 of set 11 | acajutla
# Processing Record 36 of set 11 | san andres
# Processing Record 37 of set 11 | ossora
# Processing Record 38 of set 11 | kalmar
# Processing Record 39 of set 11 | karakol
# Processing Record 40 of set 11 | solnechnyy
# Processing Record 41 of set 11 | samusu
# City not found. Skipping...
# Processing Record 42 of set 11 | bull savanna
# Processing Record 43 of set 11 | necochea
# Processing Record 44 of set 11 | nouakchott
# Processing Record 45 of set 11 | raga
# Processing Record 46 of set 11 | paranhos
# Processing Record 47 of set 11 | safranbolu
# Processing Record 48 of set 11 | pafos
# Processing Record 49 of set 11 | eucaliptus
# Processing Record 50 of set 11 | scarborough
# Processing Record 1 of set 12 | rundu
# Processing Record 2 of set 12 | namatanai
# Processing Record 3 of set 12 | waki
# Processing Record 4 of set 12 | westport
# Processing Record 5 of set 12 | beyneu
# Processing Record 6 of set 12 | ulladulla
# Processing Record 7 of set 12 | karratha
# Processing Record 8 of set 12 | cockburn town
# Processing Record 9 of set 12 | maldonado
# Processing Record 10 of set 12 | cacapava do sul
# Processing Record 11 of set 12 | tan an
# Processing Record 12 of set 12 | dese
# Processing Record 13 of set 12 | te anau
# Processing Record 14 of set 12 | tumannyy
# City not found. Skipping...
# Processing Record 15 of set 12 | sorong
# Processing Record 16 of set 12 | ivanovka
# Processing Record 17 of set 12 | gallup
# Processing Record 18 of set 12 | bukama
# Processing Record 19 of set 12 | svetlaya
# Processing Record 20 of set 12 | leningradskiy
# Processing Record 21 of set 12 | trinidad
# Processing Record 22 of set 12 | rangapara
# Processing Record 23 of set 12 | teguldet
# Processing Record 24 of set 12 | whitehorse
# Processing Record 25 of set 12 | shakiso
# Processing Record 26 of set 12 | gulshat
# City not found. Skipping...
# Processing Record 27 of set 12 | yatou
# Processing Record 28 of set 12 | tawnat
# City not found. Skipping...
# Processing Record 29 of set 12 | palmer
# Processing Record 30 of set 12 | kailua
# Processing Record 31 of set 12 | kavaratti
# Processing Record 32 of set 12 | havelock
# Processing Record 33 of set 12 | kerema
# Processing Record 34 of set 12 | buchanan
# Processing Record 35 of set 12 | hoquiam
# Processing Record 36 of set 12 | boralday
# Processing Record 37 of set 12 | touros
# Processing Record 38 of set 12 | okahandja
# Processing Record 39 of set 12 | paamiut
# Processing Record 40 of set 12 | olafsvik
# Processing Record 41 of set 12 | epe
# Processing Record 42 of set 12 | pitimbu
# Processing Record 43 of set 12 | murray bridge
# Processing Record 44 of set 12 | guisa
# Processing Record 45 of set 12 | palmas
# Processing Record 46 of set 12 | glens falls
# Processing Record 47 of set 12 | tautira
# Processing Record 48 of set 12 | samatau
# City not found. Skipping...
# Processing Record 49 of set 12 | viligili
# City not found. Skipping...
# Processing Record 50 of set 12 | turgutlu
# Processing Record 1 of set 13 | shimoda
# Processing Record 2 of set 13 | newport
# Processing Record 3 of set 13 | san pedro
# Processing Record 4 of set 13 | harper
# Processing Record 5 of set 13 | jiuquan
# Processing Record 6 of set 13 | broome
# Processing Record 7 of set 13 | san juan
# Processing Record 8 of set 13 | waitara
# Processing Record 9 of set 13 | cisarua
# Processing Record 10 of set 13 | hailar
# Processing Record 11 of set 13 | ugoofaaru
# Processing Record 12 of set 13 | zalantun
# Processing Record 13 of set 13 | karaul
# City not found. Skipping...
# Processing Record 14 of set 13 | katherine
# Processing Record 15 of set 13 | bhimavaram
# Processing Record 16 of set 13 | sigli
# Processing Record 17 of set 13 | northam
# Processing Record 18 of set 13 | aklavik
# Processing Record 19 of set 13 | nuuk
# Processing Record 20 of set 13 | mecca
# Processing Record 21 of set 13 | uniao da victoria
# City not found. Skipping...
# Processing Record 22 of set 13 | chernyshevskiy
# Processing Record 23 of set 13 | bocaranga
# City not found. Skipping...
# Processing Record 24 of set 13 | minna
# Processing Record 25 of set 13 | denpasar
# Processing Record 26 of set 13 | pastavy
# Processing Record 27 of set 13 | athabasca
# Processing Record 28 of set 13 | los alamos
# Processing Record 29 of set 13 | severo-yeniseyskiy
# Processing Record 30 of set 13 | gurskoye
# City not found. Skipping...
# Processing Record 31 of set 13 | nanakuli
# Processing Record 32 of set 13 | kjollefjord
# Processing Record 33 of set 13 | dangriga
# Processing Record 34 of set 13 | aravete
# Processing Record 35 of set 13 | vallenar
# Processing Record 36 of set 13 | anloga
# Processing Record 37 of set 13 | lake city
# Processing Record 38 of set 13 | waspan
# Processing Record 39 of set 13 | mbarara
# Processing Record 40 of set 13 | asfi
# Processing Record 41 of set 13 | ushumun
# Processing Record 42 of set 13 | inirida
# Processing Record 43 of set 13 | palu
# Processing Record 44 of set 13 | kaitangata
# Processing Record 45 of set 13 | formoso do araguaia
# City not found. Skipping...
# Processing Record 46 of set 13 | iskateley
# Processing Record 47 of set 13 | byron bay
# Processing Record 48 of set 13 | bonavista
# Processing Record 49 of set 13 | taclobo
# Processing Record 50 of set 13 | gijon
# Processing Record 1 of set 14 | labutta
# City not found. Skipping...
# Processing Record 2 of set 14 | sibu
# Processing Record 3 of set 14 | beni mazar
# Processing Record 4 of set 14 | umm lajj
# Processing Record 5 of set 14 | gold coast
# Processing Record 6 of set 14 | saulkrasti
# Processing Record 7 of set 14 | kaihua
# Processing Record 8 of set 14 | lukovit
# Processing Record 9 of set 14 | sibolga
# Processing Record 10 of set 14 | muisne
# Processing Record 11 of set 14 | tadine
# Processing Record 12 of set 14 | svetlyy
# Processing Record 13 of set 14 | lingao
# Processing Record 14 of set 14 | kerki
# City not found. Skipping...
# Processing Record 15 of set 14 | banmo
# City not found. Skipping...
# Processing Record 16 of set 14 | beringovskiy
# Processing Record 17 of set 14 | kanniyakumari
# Processing Record 18 of set 14 | mahe
# Processing Record 19 of set 14 | tiznit
# Processing Record 20 of set 14 | kismayo
# Processing Record 21 of set 14 | madang
# Processing Record 22 of set 14 | solovetskiy
# City not found. Skipping...
# Processing Record 23 of set 14 | keetmanshoop
# Processing Record 24 of set 14 | nyagan
# Processing Record 25 of set 14 | grindavik
# Processing Record 26 of set 14 | kamaishi
# Processing Record 27 of set 14 | awjilah
# Processing Record 28 of set 14 | matay
# Processing Record 29 of set 14 | buraydah
# Processing Record 30 of set 14 | sokoto
# Processing Record 31 of set 14 | kuching
# Processing Record 32 of set 14 | quang ngai
# Processing Record 33 of set 14 | sumbawa
# City not found. Skipping...
# Processing Record 34 of set 14 | farah
# Processing Record 35 of set 14 | garowe
# Processing Record 36 of set 14 | matagami
# Processing Record 37 of set 14 | stornoway
# Processing Record 38 of set 14 | kruisfontein
# Processing Record 39 of set 14 | temaraia
# City not found. Skipping...
# Processing Record 40 of set 14 | lujan
# Processing Record 41 of set 14 | hovd
# Processing Record 42 of set 14 | morant bay
# Processing Record 43 of set 14 | lauro muller
# Processing Record 44 of set 14 | lawton
# Processing Record 45 of set 14 | conde
# Processing Record 46 of set 14 | abu samrah
# Processing Record 47 of set 14 | jaque
# Processing Record 48 of set 14 | morehead
# Processing Record 49 of set 14 | magdagachi
# Processing Record 50 of set 14 | aste
# Processing Record 1 of set 15 | usinsk
# Processing Record 2 of set 15 | lavumisa
# Processing Record 3 of set 15 | ballina
# Processing Record 4 of set 15 | alyangula
# Processing Record 5 of set 15 | koath
# Processing Record 6 of set 15 | skibbereen
# Processing Record 7 of set 15 | sevierville
# Processing Record 8 of set 15 | sisophon
# Processing Record 9 of set 15 | axixa do tocantins
# City not found. Skipping...
# Processing Record 10 of set 15 | ayios matthaios
# City not found. Skipping...
# Processing Record 11 of set 15 | tilichiki
# Processing Record 12 of set 15 | lisakovsk
# Processing Record 13 of set 15 | erdenet
# Processing Record 14 of set 15 | londa
# Processing Record 15 of set 15 | cockburn harbour
# City not found. Skipping...
# Processing Record 16 of set 15 | qena
# Processing Record 17 of set 15 | omboue
# Processing Record 18 of set 15 | gigmoto
# Processing Record 19 of set 15 | qianan
# Processing Record 20 of set 15 | acarau
# Processing Record 21 of set 15 | ardesen
# -------------------------------
# Data Retrieval Complete
# -------------------------------

# %%
city_data_df = pd.DataFrame(city_data)

city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Pisco      PE -13.7000  -76.2167     59.02        88          17
# 1       Xuddur      SO   4.1213   43.8894     67.86        82          38
# 2        Avera      US  33.1940  -82.5271     77.05        81          59
# 3  Yellowknife      CA  62.4560 -114.3525     66.56        72          44
# 4      Ushuaia      AR -54.8000  -68.3000     37.06        70          40
# 5    Jamestown      US  42.0970  -79.2353     67.64        72           0
# 6       Castro      BR -24.7911  -50.0119     67.33        63         100
# 7      Ritchie      ZA -29.0380   24.6028     49.73        44           0
# 8     Petatlan      MX  17.5167 -101.2667     77.25        94         100
# 9    Tuatapere      NZ -46.1333  167.6833     47.16        89          89
#
#    Wind Speed Current Description
# 0        5.75                mist
# 1       19.57    scattered clouds
# 2        6.04       broken clouds
# 3       11.99    scattered clouds
# 4        2.30    scattered clouds
# 5        1.01           clear sky
# 6       10.60     overcast clouds
# 7        6.11           clear sky
# 8        6.53     overcast clouds
# 9        8.99     overcast clouds

# %%
# saving DataFrame as a csv

output_data_file = "Weather_Database/WeatherPy_Database.csv"

city_data_df.to_csv(output_data_file, index_label="City_ID")
